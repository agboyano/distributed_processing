# %%
from distributed_rpc.serializers import JsonSerializer
from distributed_rpc.rpc_server import RPCServer
from distributed_rpc.redis_connector import RedisConnector

# %%
REDIS_HOST = "localhost"
REDIS_PORT = 6379
REDIS_DB = 0
NAMESPACE = "montecarlo"

# %%
redis_connector = RedisConnector(redis_host=REDIS_HOST, redis_port=REDIS_PORT, 
                                 redis_db=REDIS_DB, namespace=NAMESPACE)


redis_connector.clean_namespace()

server = RPCServer(JsonSerializer(), redis_connector)

# %%
import datetime
from math import exp, sqrt
import numpy as np

def new_price(S_t, v, r, t1, t2):
    T = (t2 - t1) / 365.0
    return S_t * exp((r - 0.5 * v * v) * T + v * sqrt(T) * np.random.randn()) # no hay diferencia con gauss


def df(r, t1, t2):
    return exp(-r * (t2 - t1) / 365.0)


def mc_autocall_mp(simulations,
                   v,
                   r, 
                   coupon_barrier,
                   kickout_barrier,
                   protection_barrier,
                   coupon_rate,
                   dates):
    
    simulations = int(simulations) # Cuidado con los enteros en json son todo flotantes
    
    assert(coupon_barrier >= protection_barrier)
    
    S = 1.0
    C = 1000.0

    start_date = dates[0]

    autocall_prices = [0.0] * simulations # Cuidado con los enteros en json son todo flotantes

    coupons_discounted = [C * coupon_rate * df(r, start_date, dates[j]) for j in range(len(dates))]
    principal_discounted = [C * df(r, start_date, dates[j]) for j in range(len(dates))]
    
    def p_exp(t1, t2):
        T = (t2 - t1) / 365.0
        return ((r - 0.5 * v**2) * T, v * sqrt(T)) 
        
    
    partial_exp = [p_exp(dates[j], dates[j+1]) for j in range(len(dates)-1)]
    
    rnd = np.random.RandomState().randn(simulations, len(dates)-1) 
    
    # muy importante RandomState() para multiproceso ya que reinicializa la semilla
    
    for i in range(simulations):
        autocall_price = 0.0
        
        for j in range(1, len(dates)):
            S = S * exp(partial_exp[j-1][0] + partial_exp[j-1][1] * rnd[i, j-1]) 
    
            if S > coupon_barrier:
                autocall_price += coupons_discounted[j]
                
            if S >= kickout_barrier:
                break

        if S < protection_barrier:
            autocall_price += S * principal_discounted[j]
                
        else:
            autocall_price += principal_discounted[j]

        autocall_prices[i] = autocall_price

    return sum(autocall_prices) , float(simulations)

# %%
server.add_requests_queue("cola_1", {"mc_autocall_mp":mc_autocall_mp})
server.update_methods_registry()
# Out:
# Method mc_autocall_mp published as available for queues: montecarlo:requests:cola_1

# %%
server.run()
# Out:
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:1 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:1 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:2 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:2 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:3 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:3 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:4 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:4 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:5 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:5 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:6 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:6 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:7 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:7 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:8 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:8 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:9 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:9 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:10 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:10 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:11 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:11 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:12 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:12 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:13 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:13 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:14 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:14 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:15 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:15 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:16 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:16 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:17 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:17 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:18 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:18 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:19 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:19 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:20 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:20 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:21 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:21 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:22 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:22 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:23 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:23 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:24 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:24 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:25 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:25 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:26 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:26 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:27 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:27 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:28 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:28 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:29 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:29 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:30 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:30 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:31 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:31 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:32 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:32 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:33 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:33 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:34 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:34 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:35 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:35 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:36 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:36 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:37 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:37 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:38 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:38 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:39 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:39 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:40 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:40 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:41 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:41 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:42 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:42 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:43 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:43 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:44 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:44 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:45 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:45 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:46 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:46 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:47 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:47 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:48 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:48 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:49 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:49 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:50 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:50 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:51 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:51 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:52 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:52 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:53 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:53 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:54 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:54 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:55 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:55 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:56 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:56 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:57 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:57 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:58 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:58 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:59 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:59 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:60 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:60 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:61 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:61 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:62 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:62 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:63 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:63 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:64 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:64 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:65 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:65 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:66 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:66 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:67 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:67 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:68 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:68 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:69 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:69 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:70 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:70 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:71 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:71 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:72 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:72 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:73 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:73 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:74 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:74 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:75 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:75 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:76 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:76 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:77 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:77 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:78 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:78 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:79 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:79 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:80 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:80 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:81 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:81 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:82 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:82 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:83 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:83 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:84 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:84 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:85 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:85 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:86 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:86 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:87 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:87 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:88 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:88 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:89 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:89 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:90 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:90 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:91 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:91 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:92 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:92 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:93 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:93 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:94 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:94 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:95 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:95 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:96 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:96 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:97 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:97 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:98 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:98 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:99 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:99 sent to montecarlo:redis_client:1:responses
# Recieved single request in queue montecarlo:requests:cola_1
# Processed request with id montecarlo:redis_client:1:100 in queue montecarlo:requests:cola_1
# Response with id montecarlo:redis_client:1:100 sent to montecarlo:redis_client:1:responses
