# %%
from distributed_processing.serializers import DummySerializer
from distributed_processing.worker import Worker
from distributed_processing.filesystem_connector import FileSystemConnector

from time import sleep

# %%
CURRO = True

if CURRO:
    NS_PATH ="G:\\fs_namespaces\\prueba_distribuida"
    NS_PATH ="C:\\fs_namespaces\\prueba_distribuida"

else:
    NS_PATH = "/home/augusto/python/notebooks/fs_namespaces/prueba_distribuida"

# %%
import logging
logging.getLogger("distributed_processing").setLevel(logging.DEBUG)

# %%
fs_connector = FileSystemConnector(NS_PATH)
fs_connector.with_watchdog = True
# Podemos limpiar el namespace por si quedan restos de ejecuciones anteriores.
#fs_connector.clean_namespace()

server = Worker(DummySerializer(), fs_connector)
# Out:
# nservers_lock set
# nservers_lock unset
# Worker id: fs_server_1

# %%
def add(x, y):
    return x + y

def mul(x, y):
    return x * y

def div(x, y):
    return x / y

def lista(x, y):
    return [x, y]

def tupla(x, y):
    return (x,y)

def dic(x,y):
    return {"a":x, "b":[x,y]}

func_dict1 = {"add" : add,
              "mul" : mul,
              "div" : div,
              "lista" : lista,
              "tupla" : tupla,
              "dic" :dic,
              "sleep": sleep}

server.add_requests_queue("cola_1", func_dict1)

# %%
def hola(nombre, calificativo="listo"):
    return f"Hola {nombre}, eres muy {calificativo}"

func_dict2 = {"hola": hola}

# Los métodos disponibles en cola_2 no los vamos a hacer públicos
server.add_requests_queue("cola_2", func_dict2, register=False)

# %%
server.add_python_eval()

"""
# Equivalente a:
import dill
import base64

def eval_py_function(str_fn, args=[], kwargs={}):
    "str_fn encoded en base64 ascii"
    return dill.loads(base64.b64decode(str_fn))(*args, **kwargs)

server.add_requests_queue("py_eval", {"eval_py_function": eval_py_function})
"""
# Out:
# '\n# Equivalente a:\nimport dill\nimport base64\n\ndef eval_py_function(str_fn, args=[], kwargs={}):\n    "str_fn encoded en base64 ascii"\n    return dill.loads(base64.b64decode(str_fn))(*args, **kwargs)\n\nserver.add_requests_queue("py_eval", {"eval_py_function": eval_py_function})\n'

# %%
server.queues_to_register
# Out:
# {'requests_cola_1', 'requests_py_eval'}

# %%
# Publicamos todos los métodos de las colas 
server.update_methods_registry()
# Out:
# registry_lock set
# Method add published as available for queues: requests_cola_1
# Method mul published as available for queues: requests_cola_1
# Method div published as available for queues: requests_cola_1
# Method lista published as available for queues: requests_cola_1
# Method tupla published as available for queues: requests_cola_1
# Method dic published as available for queues: requests_cola_1
# Method sleep published as available for queues: requests_cola_1
# Method eval_py_function published as available for queues: requests_py_eval
# registry_lock unset

# %%
server.run()
# Out:
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:1 in queue requests_cola_1
# Response with id fs_client_1:1 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:2 in queue requests_cola_1
# Response with id fs_client_1:2 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:3 in queue requests_cola_1
# Response with id fs_client_1:3 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:4 in queue requests_cola_1
# Response with id fs_client_1:4 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:5 in queue requests_cola_1
# Response with id fs_client_1:5 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_py_eval
# ****** Single response *******
# Processed request with id fs_client_1:6 in queue requests_py_eval
# Response with id fs_client_1:6 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_py_eval
# ****** Single response *******
# Processed request with id fs_client_1:7 in queue requests_py_eval
# Response with id fs_client_1:7 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:8 in queue requests_cola_1
# Response with id fs_client_1:8 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:9 in queue requests_cola_1
# Response with id fs_client_1:9 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:10 in queue requests_cola_1
# Response with id fs_client_1:10 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:11 in queue requests_cola_1
# Response with id fs_client_1:11 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:12 in queue requests_cola_1
# Response with id fs_client_1:12 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:13 in queue requests_cola_1
# Response with id fs_client_1:13 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:14 in queue requests_cola_1
# Response with id fs_client_1:14 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:15 in queue requests_cola_1
# Response with id fs_client_1:15 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:16 in queue requests_cola_1
# Response with id fs_client_1:16 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:17 in queue requests_cola_1
# Response with id fs_client_1:17 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:18 in queue requests_cola_1
# Response with id fs_client_1:18 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:19 in queue requests_cola_1
# Response with id fs_client_1:19 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:20 in queue requests_cola_1
# Response with id fs_client_1:20 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:21 in queue requests_cola_1
# Response with id fs_client_1:21 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:22 in queue requests_cola_1
# Response with id fs_client_1:22 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:23 in queue requests_cola_1
# Response with id fs_client_1:23 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:24 in queue requests_cola_1
# Response with id fs_client_1:24 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:25 in queue requests_cola_1
# Response with id fs_client_1:25 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:26 in queue requests_cola_1
# Response with id fs_client_1:26 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:27 in queue requests_cola_1
# Response with id fs_client_1:27 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:28 in queue requests_cola_1
# Response with id fs_client_1:28 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:29 in queue requests_cola_1
# Response with id fs_client_1:29 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received batch request in queue requests_cola_1
# Processed request with id fs_client_1:30 in queue requests_cola_1
# Response with id fs_client_1:30 sent to fs_client_1_responses
# Processed request with id fs_client_1:31 in queue requests_cola_1
# Response with id fs_client_1:31 sent to fs_client_1_responses
# Processed request with id fs_client_1:32 in queue requests_cola_1
# Response with id fs_client_1:32 sent to fs_client_1_responses
# Processed request with id fs_client_1:33 in queue requests_cola_1
# Response with id fs_client_1:33 sent to fs_client_1_responses
# Processed request with id fs_client_1:34 in queue requests_cola_1
# Response with id fs_client_1:34 sent to fs_client_1_responses
# Processed request with id fs_client_1:35 in queue requests_cola_1
# Response with id fs_client_1:35 sent to fs_client_1_responses
# Processed request with id fs_client_1:36 in queue requests_cola_1
# Response with id fs_client_1:36 sent to fs_client_1_responses
# Processed request with id fs_client_1:37 in queue requests_cola_1
# Response with id fs_client_1:37 sent to fs_client_1_responses
# Processed request with id fs_client_1:38 in queue requests_cola_1
# Response with id fs_client_1:38 sent to fs_client_1_responses
# Processed request with id fs_client_1:39 in queue requests_cola_1
# Response with id fs_client_1:39 sent to fs_client_1_responses
# Processed request with id fs_client_1:40 in queue requests_cola_1
# Response with id fs_client_1:40 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received batch request in queue requests_cola_1
# Processed request with id fs_client_1:41 in queue requests_cola_1
# Response with id fs_client_1:41 sent to fs_client_1_responses
# Processed request with id fs_client_1:42 in queue requests_cola_1
# Response with id fs_client_1:42 sent to fs_client_1_responses
# Processed request with id fs_client_1:43 in queue requests_cola_1
# Response with id fs_client_1:43 sent to fs_client_1_responses
# Processed request with id fs_client_1:44 in queue requests_cola_1
# Response with id fs_client_1:44 sent to fs_client_1_responses
# Processed request with id fs_client_1:45 in queue requests_cola_1
# Response with id fs_client_1:45 sent to fs_client_1_responses
# Processed request with id fs_client_1:46 in queue requests_cola_1
# Response with id fs_client_1:46 sent to fs_client_1_responses
# Processed request with id fs_client_1:47 in queue requests_cola_1
# Response with id fs_client_1:47 sent to fs_client_1_responses
# Processed request with id fs_client_1:48 in queue requests_cola_1
# Response with id fs_client_1:48 sent to fs_client_1_responses
# Processed request with id fs_client_1:49 in queue requests_cola_1
# Response with id fs_client_1:49 sent to fs_client_1_responses
# Processed request with id fs_client_1:50 in queue requests_cola_1
# Response with id fs_client_1:50 sent to fs_client_1_responses
# Processed request with id fs_client_1:51 in queue requests_cola_1
# Response with id fs_client_1:51 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received batch request in queue requests_cola_1
# Processed request with id fs_client_1:52 in queue requests_cola_1
# Response with id fs_client_1:52 sent to fs_client_1_responses
# Processed request with id fs_client_1:53 in queue requests_cola_1
# Response with id fs_client_1:53 sent to fs_client_1_responses
# Processed request with id fs_client_1:54 in queue requests_cola_1
# Response with id fs_client_1:54 sent to fs_client_1_responses
# Processed request with id fs_client_1:55 in queue requests_cola_1
# Response with id fs_client_1:55 sent to fs_client_1_responses
# Processed request with id fs_client_1:56 in queue requests_cola_1
# Response with id fs_client_1:56 sent to fs_client_1_responses
# Processed request with id fs_client_1:57 in queue requests_cola_1
# Response with id fs_client_1:57 sent to fs_client_1_responses
# Processed request with id fs_client_1:58 in queue requests_cola_1
# Response with id fs_client_1:58 sent to fs_client_1_responses
# Processed request with id fs_client_1:59 in queue requests_cola_1
# Response with id fs_client_1:59 sent to fs_client_1_responses
# Processed request with id fs_client_1:60 in queue requests_cola_1
# Response with id fs_client_1:60 sent to fs_client_1_responses
# Processed request with id fs_client_1:61 in queue requests_cola_1
# Response with id fs_client_1:61 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:62 in queue requests_cola_1
# Response with id fs_client_1:62 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:63 in queue requests_cola_1
# Response with id fs_client_1:63 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:64 in queue requests_cola_1
# Response with id fs_client_1:64 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_py_eval
# ****** Single response *******
# Processed request with id fs_client_1:65 in queue requests_py_eval
# Response with id fs_client_1:65 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_py_eval
# ****** Single response *******
# Processed request with id fs_client_1:66 in queue requests_py_eval
# Response with id fs_client_1:66 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# hola
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:67 in queue requests_cola_1
# Response with id fs_client_1:67 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:68 in queue requests_cola_1
# Response with id fs_client_1:68 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:69 in queue requests_cola_1
# Response with id fs_client_1:69 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:70 in queue requests_cola_1
# Response with id fs_client_1:70 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:71 in queue requests_cola_1
# Response with id fs_client_1:71 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:72 in queue requests_cola_1
# Response with id fs_client_1:72 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:73 in queue requests_cola_1
# Response with id fs_client_1:73 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:74 in queue requests_cola_1
# Response with id fs_client_1:74 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:75 in queue requests_cola_1
# Response with id fs_client_1:75 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:76 in queue requests_cola_1
# Response with id fs_client_1:76 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:77 in queue requests_cola_1
# Response with id fs_client_1:77 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:78 in queue requests_cola_1
# Response with id fs_client_1:78 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:79 in queue requests_cola_1
# Response with id fs_client_1:79 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:80 in queue requests_cola_1
# Response with id fs_client_1:80 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:81 in queue requests_cola_1
# Response with id fs_client_1:81 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:82 in queue requests_cola_1
# Response with id fs_client_1:82 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:83 in queue requests_cola_1
# Response with id fs_client_1:83 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:84 in queue requests_cola_1
# Response with id fs_client_1:84 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:85 in queue requests_cola_1
# Response with id fs_client_1:85 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:86 in queue requests_cola_1
# Response with id fs_client_1:86 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:87 in queue requests_cola_1
# Response with id fs_client_1:87 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_1:88 in queue requests_cola_1
# Response with id fs_client_1:88 sent to fs_client_1_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:1 in queue requests_cola_1
# Response with id fs_client_2:1 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:2 in queue requests_cola_1
# Response with id fs_client_2:2 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:3 in queue requests_cola_1
# Response with id fs_client_2:3 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:4 in queue requests_cola_1
# Response with id fs_client_2:4 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:5 in queue requests_cola_1
# Response with id fs_client_2:5 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_py_eval
# ****** Single response *******
# Processed request with id fs_client_2:6 in queue requests_py_eval
# Response with id fs_client_2:6 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_py_eval
# ****** Single response *******
# Processed request with id fs_client_2:7 in queue requests_py_eval
# Response with id fs_client_2:7 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:8 in queue requests_cola_1
# Response with id fs_client_2:8 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:9 in queue requests_cola_1
# Response with id fs_client_2:9 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:10 in queue requests_cola_1
# Response with id fs_client_2:10 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:11 in queue requests_cola_1
# Response with id fs_client_2:11 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:12 in queue requests_cola_1
# Response with id fs_client_2:12 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:13 in queue requests_cola_1
# Response with id fs_client_2:13 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:14 in queue requests_cola_1
# Response with id fs_client_2:14 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:15 in queue requests_cola_1
# Response with id fs_client_2:15 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:16 in queue requests_cola_1
# Response with id fs_client_2:16 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:17 in queue requests_cola_1
# Response with id fs_client_2:17 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:18 in queue requests_cola_1
# Response with id fs_client_2:18 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:19 in queue requests_cola_1
# Response with id fs_client_2:19 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:20 in queue requests_cola_1
# Response with id fs_client_2:20 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:21 in queue requests_cola_1
# Response with id fs_client_2:21 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:22 in queue requests_cola_1
# Response with id fs_client_2:22 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:23 in queue requests_cola_1
# Response with id fs_client_2:23 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:24 in queue requests_cola_1
# Response with id fs_client_2:24 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:25 in queue requests_cola_1
# Response with id fs_client_2:25 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:26 in queue requests_cola_1
# Response with id fs_client_2:26 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:27 in queue requests_cola_1
# Response with id fs_client_2:27 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:28 in queue requests_cola_1
# Response with id fs_client_2:28 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_2:29 in queue requests_cola_1
# Response with id fs_client_2:29 sent to fs_client_2_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:1 in queue requests_cola_1
# Response with id fs_client_3:1 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:2 in queue requests_cola_1
# Response with id fs_client_3:2 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:3 in queue requests_cola_1
# Response with id fs_client_3:3 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:4 in queue requests_cola_1
# Response with id fs_client_3:4 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:5 in queue requests_cola_1
# Response with id fs_client_3:5 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_py_eval
# ****** Single response *******
# Processed request with id fs_client_3:6 in queue requests_py_eval
# Response with id fs_client_3:6 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_py_eval
# ****** Single response *******
# Processed request with id fs_client_3:7 in queue requests_py_eval
# Response with id fs_client_3:7 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:8 in queue requests_cola_1
# Response with id fs_client_3:8 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:9 in queue requests_cola_1
# Response with id fs_client_3:9 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:10 in queue requests_cola_1
# Response with id fs_client_3:10 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:11 in queue requests_cola_1
# Response with id fs_client_3:11 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:12 in queue requests_cola_1
# Response with id fs_client_3:12 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:13 in queue requests_cola_1
# Response with id fs_client_3:13 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:14 in queue requests_cola_1
# Response with id fs_client_3:14 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:15 in queue requests_cola_1
# Response with id fs_client_3:15 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:16 in queue requests_cola_1
# Response with id fs_client_3:16 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:17 in queue requests_cola_1
# Response with id fs_client_3:17 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:18 in queue requests_cola_1
# Response with id fs_client_3:18 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:19 in queue requests_cola_1
# Response with id fs_client_3:19 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:20 in queue requests_cola_1
# Response with id fs_client_3:20 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:21 in queue requests_cola_1
# Response with id fs_client_3:21 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:22 in queue requests_cola_1
# Response with id fs_client_3:22 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:23 in queue requests_cola_1
# Response with id fs_client_3:23 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:24 in queue requests_cola_1
# Response with id fs_client_3:24 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:25 in queue requests_cola_1
# Response with id fs_client_3:25 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:26 in queue requests_cola_1
# Response with id fs_client_3:26 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:27 in queue requests_cola_1
# Response with id fs_client_3:27 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:28 in queue requests_cola_1
# Response with id fs_client_3:28 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:29 in queue requests_cola_1
# Response with id fs_client_3:29 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received batch request in queue requests_cola_1
# Processed request with id fs_client_3:30 in queue requests_cola_1
# Response with id fs_client_3:30 sent to fs_client_3_responses
# Processed request with id fs_client_3:31 in queue requests_cola_1
# Response with id fs_client_3:31 sent to fs_client_3_responses
# Processed request with id fs_client_3:32 in queue requests_cola_1
# Response with id fs_client_3:32 sent to fs_client_3_responses
# Processed request with id fs_client_3:33 in queue requests_cola_1
# Response with id fs_client_3:33 sent to fs_client_3_responses
# Processed request with id fs_client_3:34 in queue requests_cola_1
# Response with id fs_client_3:34 sent to fs_client_3_responses
# Processed request with id fs_client_3:35 in queue requests_cola_1
# Response with id fs_client_3:35 sent to fs_client_3_responses
# Processed request with id fs_client_3:36 in queue requests_cola_1
# Response with id fs_client_3:36 sent to fs_client_3_responses
# Processed request with id fs_client_3:37 in queue requests_cola_1
# Response with id fs_client_3:37 sent to fs_client_3_responses
# Processed request with id fs_client_3:38 in queue requests_cola_1
# Response with id fs_client_3:38 sent to fs_client_3_responses
# Processed request with id fs_client_3:39 in queue requests_cola_1
# Response with id fs_client_3:39 sent to fs_client_3_responses
# Processed request with id fs_client_3:40 in queue requests_cola_1
# Response with id fs_client_3:40 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received batch request in queue requests_cola_1
# Processed request with id fs_client_3:41 in queue requests_cola_1
# Response with id fs_client_3:41 sent to fs_client_3_responses
# Processed request with id fs_client_3:42 in queue requests_cola_1
# Response with id fs_client_3:42 sent to fs_client_3_responses
# Processed request with id fs_client_3:43 in queue requests_cola_1
# Response with id fs_client_3:43 sent to fs_client_3_responses
# Processed request with id fs_client_3:44 in queue requests_cola_1
# Response with id fs_client_3:44 sent to fs_client_3_responses
# Processed request with id fs_client_3:45 in queue requests_cola_1
# Response with id fs_client_3:45 sent to fs_client_3_responses
# Processed request with id fs_client_3:46 in queue requests_cola_1
# Response with id fs_client_3:46 sent to fs_client_3_responses
# Processed request with id fs_client_3:47 in queue requests_cola_1
# Response with id fs_client_3:47 sent to fs_client_3_responses
# Processed request with id fs_client_3:48 in queue requests_cola_1
# Response with id fs_client_3:48 sent to fs_client_3_responses
# Processed request with id fs_client_3:49 in queue requests_cola_1
# Response with id fs_client_3:49 sent to fs_client_3_responses
# Processed request with id fs_client_3:50 in queue requests_cola_1
# Response with id fs_client_3:50 sent to fs_client_3_responses
# Processed request with id fs_client_3:51 in queue requests_cola_1
# Response with id fs_client_3:51 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received batch request in queue requests_cola_1
# Processed request with id fs_client_3:52 in queue requests_cola_1
# Response with id fs_client_3:52 sent to fs_client_3_responses
# Processed request with id fs_client_3:53 in queue requests_cola_1
# Response with id fs_client_3:53 sent to fs_client_3_responses
# Processed request with id fs_client_3:54 in queue requests_cola_1
# Response with id fs_client_3:54 sent to fs_client_3_responses
# Processed request with id fs_client_3:55 in queue requests_cola_1
# Response with id fs_client_3:55 sent to fs_client_3_responses
# Processed request with id fs_client_3:56 in queue requests_cola_1
# Response with id fs_client_3:56 sent to fs_client_3_responses
# Processed request with id fs_client_3:57 in queue requests_cola_1
# Response with id fs_client_3:57 sent to fs_client_3_responses
# Processed request with id fs_client_3:58 in queue requests_cola_1
# Response with id fs_client_3:58 sent to fs_client_3_responses
# Processed request with id fs_client_3:59 in queue requests_cola_1
# Response with id fs_client_3:59 sent to fs_client_3_responses
# Processed request with id fs_client_3:60 in queue requests_cola_1
# Response with id fs_client_3:60 sent to fs_client_3_responses
# Processed request with id fs_client_3:61 in queue requests_cola_1
# Response with id fs_client_3:61 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:62 in queue requests_cola_1
# Response with id fs_client_3:62 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:63 in queue requests_cola_1
# Response with id fs_client_3:63 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:64 in queue requests_cola_1
# Response with id fs_client_3:64 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_py_eval
# ****** Single response *******
# Processed request with id fs_client_3:65 in queue requests_py_eval
# Response with id fs_client_3:65 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_py_eval
# ****** Single response *******
# Processed request with id fs_client_3:66 in queue requests_py_eval
# Response with id fs_client_3:66 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# hola
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:67 in queue requests_cola_1
# Response with id fs_client_3:67 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:68 in queue requests_cola_1
# Response with id fs_client_3:68 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:69 in queue requests_cola_1
# Response with id fs_client_3:69 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:70 in queue requests_cola_1
# Response with id fs_client_3:70 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:71 in queue requests_cola_1
# Response with id fs_client_3:71 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:72 in queue requests_cola_1
# Response with id fs_client_3:72 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:73 in queue requests_cola_1
# Response with id fs_client_3:73 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:74 in queue requests_cola_1
# Response with id fs_client_3:74 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:75 in queue requests_cola_1
# Response with id fs_client_3:75 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:76 in queue requests_cola_1
# Response with id fs_client_3:76 sent to fs_client_3_responses
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_3:77 in queue requests_cola_1
# ...
# Response with id fs_client_10:30 sent to fs_client_10_responses
# Processed request with id fs_client_10:31 in queue requests_cola_1
# Response with id fs_client_10:31 sent to fs_client_10_responses
# Processed request with id fs_client_10:32 in queue requests_cola_1
# Response with id fs_client_10:32 sent to fs_client_10_responses
# Processed request with id fs_client_10:33 in queue requests_cola_1
# Response with id fs_client_10:33 sent to fs_client_10_responses
# Processed request with id fs_client_10:34 in queue requests_cola_1
# Response with id fs_client_10:34 sent to fs_client_10_responses
# Processed request with id fs_client_10:35 in queue requests_cola_1
# Response with id fs_client_10:35 sent to fs_client_10_responses
# Processed request with id fs_client_10:36 in queue requests_cola_1
# Response with id fs_client_10:36 sent to fs_client_10_responses
# Processed request with id fs_client_10:37 in queue requests_cola_1
# Response with id fs_client_10:37 sent to fs_client_10_responses
# Processed request with id fs_client_10:38 in queue requests_cola_1
# Response with id fs_client_10:38 sent to fs_client_10_responses
# Processed request with id fs_client_10:39 in queue requests_cola_1
# Response with id fs_client_10:39 sent to fs_client_10_responses
# Processed request with id fs_client_10:40 in queue requests_cola_1
# Response with id fs_client_10:40 sent to fs_client_10_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received batch request in queue requests_cola_1
# Processed request with id fs_client_10:41 in queue requests_cola_1
# Response with id fs_client_10:41 sent to fs_client_10_responses
# Processed request with id fs_client_10:42 in queue requests_cola_1
# Response with id fs_client_10:42 sent to fs_client_10_responses
# Processed request with id fs_client_10:43 in queue requests_cola_1
# Response with id fs_client_10:43 sent to fs_client_10_responses
# Processed request with id fs_client_10:44 in queue requests_cola_1
# Response with id fs_client_10:44 sent to fs_client_10_responses
# Processed request with id fs_client_10:45 in queue requests_cola_1
# Response with id fs_client_10:45 sent to fs_client_10_responses
# Processed request with id fs_client_10:46 in queue requests_cola_1
# Response with id fs_client_10:46 sent to fs_client_10_responses
# Processed request with id fs_client_10:47 in queue requests_cola_1
# Response with id fs_client_10:47 sent to fs_client_10_responses
# Processed request with id fs_client_10:48 in queue requests_cola_1
# Response with id fs_client_10:48 sent to fs_client_10_responses
# Processed request with id fs_client_10:49 in queue requests_cola_1
# Response with id fs_client_10:49 sent to fs_client_10_responses
# Processed request with id fs_client_10:50 in queue requests_cola_1
# Response with id fs_client_10:50 sent to fs_client_10_responses
# Processed request with id fs_client_10:51 in queue requests_cola_1
# Response with id fs_client_10:51 sent to fs_client_10_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received batch request in queue requests_cola_1
# Processed request with id fs_client_10:52 in queue requests_cola_1
# Response with id fs_client_10:52 sent to fs_client_10_responses
# Processed request with id fs_client_10:53 in queue requests_cola_1
# Response with id fs_client_10:53 sent to fs_client_10_responses
# Processed request with id fs_client_10:54 in queue requests_cola_1
# Response with id fs_client_10:54 sent to fs_client_10_responses
# Processed request with id fs_client_10:55 in queue requests_cola_1
# Response with id fs_client_10:55 sent to fs_client_10_responses
# Processed request with id fs_client_10:56 in queue requests_cola_1
# Response with id fs_client_10:56 sent to fs_client_10_responses
# Processed request with id fs_client_10:57 in queue requests_cola_1
# Response with id fs_client_10:57 sent to fs_client_10_responses
# Processed request with id fs_client_10:58 in queue requests_cola_1
# Response with id fs_client_10:58 sent to fs_client_10_responses
# Processed request with id fs_client_10:59 in queue requests_cola_1
# Response with id fs_client_10:59 sent to fs_client_10_responses
# Processed request with id fs_client_10:60 in queue requests_cola_1
# Response with id fs_client_10:60 sent to fs_client_10_responses
# Processed request with id fs_client_10:61 in queue requests_cola_1
# Response with id fs_client_10:61 sent to fs_client_10_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_10:62 in queue requests_cola_1
# Response with id fs_client_10:62 sent to fs_client_10_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_10:63 in queue requests_cola_1
# Response with id fs_client_10:63 sent to fs_client_10_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_cola_1
# ****** Single response *******
# Processed request with id fs_client_10:64 in queue requests_cola_1
# Response with id fs_client_10:64 sent to fs_client_10_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_py_eval
# ****** Single response *******
# Processed request with id fs_client_10:65 in queue requests_py_eval
# Response with id fs_client_10:65 sent to fs_client_10_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# Received single request in queue requests_py_eval
# ****** Single response *******
# Processed request with id fs_client_10:66 in queue requests_py_eval
# Response with id fs_client_10:66 sent to fs_client_10_responses
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# hola
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
# pop_left_lock set
# pop_left_lock unset
